# %%
'''
listar dados do dicionario

'''

import pandas as pd
#dicionario
dados = {'Vendedorxx' : ['Naruto','Goku','Seiya'],
         'Produto' : ['Geladeira','Fogao','Ar condicionado'],
         'Valor  vendido' : [3400, 750, 2650],
         }
df = pd.DataFrame(dados)
#df
print("="*80)
print(df)
print("="*80)
display(df)


#-------------------------------------------

print("="*80)
