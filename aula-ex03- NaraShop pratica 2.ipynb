# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
url = 'pedidos_narashop.csv'
df = pd.read_csv(url, encoding='utf8', sep=';')
df.head(10)
# Out:
#    pedido_id         vendedor         categoria                  produto  \
# 0      10001  Rafael Oliveira          Esportes  Raquete de Beach Tennis
# 1      10002     Leandro Reis       Eletrônicos              SSD Externo
# 2      10003   Flávia Azevedo       Eletrônicos                 Notebook
# 3      10004    Lucas Ribeiro          Esportes          Garrafa Térmica
# 4      10005   Vinícius Lopes       Eletrônicos              SSD Externo
# 5      10006  Diego Fernandes          Esportes    Bicicleta Ergométrica
# 6      10007      Tiago Moura  Casa e Decoração        Espelho de Parede
# 7      10008    Anderson Cruz          Esportes        Bermuda Esportiva
# 8      10009   Flávia Azevedo        Brinquedos       Pista de Carrinhos
# 9      10010    Tatiane Cunha  Casa e Decoração           Porta-Retratos
#
#   status_pedido  quantidade  valor_unitario  prazo_entrega_dias
# 0      Entregue           5           98,01                  12
# ...

# %%
# Define o formato de exibição padrão do Pandas para o padrão brasileiro
pd.options.display.float_format = lambda x: f"{x:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
#
print('vendedor: ', df['vendedor'][2],'  valor_unitario: ', df['valor_unitario'][2])
print('  valor_unitario: ', df['valor_unitario'])
print('vendedor: ', df['vendedor'][5])
# Out:
# vendedor:  Flávia Azevedo   valor_unitario:  3774.96
#   valor_unitario:  0          98,01
# 1         599,89
# 2       3.774,96
# 3          87,67
# 4         439,02
#           ...
# 19995     178,86
# 19996     166,27
# 19997   1.577,65
# 19998     144,59
# 19999      65,70
# Name: valor_unitario, Length: 20000, dtype: float64
# vendedor:  Diego Fernandes

# %%
print(f"valor unit: {df['valor_unitario'].mean()}")
# Out:
# valor unit: 842.8166460000001
