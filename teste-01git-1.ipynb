# %%
print("estou no repository github 1")
print("estou no repository github 2")
print("estou no repository github 3")
# Out:
# estou no repository github 1
# estou no repository github 2
# estou no repository github 3

# %%
print("estou no repository github 4")
